# %%
import pandas as pd

# %%
# Read the CSV file into a DataFrame with custom options.
summoners_df = pd.read_csv('summoners.csv', delimiter=',', encoding='utf-8', header=0)

# Read the CSV file into a DataFrame with custom options.
seen_df = pd.read_csv('seen.csv', delimiter=',', encoding='utf-8', header=0)

# %%
seen_df.shape
# Out:
# (8435, 1)

# %%
summoners_df.shape
# Out:
# (190434, 1)

# %%
summoners_df[summoners_df['summoner_list'] == 'I Reformed gg']
# Out:
#       summoner_list
# 1294  I Reformed gg

# %%
df = seen_df.iloc[:4999]

# %%
df.shape
# Out:
# (4999, 1)

# %%
# Save the DataFrame as a CSV file
df.to_csv('seen.csv', index=False)
